# %%
#ANN Simulation
##General preprocessing for Pandas and Graphics

# %%
from IPython.display import display
# %pylab inline
import pandas as pd

print "compile the codes"
# !make

print "Testing ann_aq code"
# !./ann_aq
# Out:
# Populating the interactive namespace from numpy and matplotlib
# compile the codes
# # ls -al --color=auto
# echo "Compilation is completed."
# Compilation is completed.
# Testing ann_aq code
# Usage-1: ann_aq mode
# Usage-2: ann_aq mode param
# Help: ann_aq
# Where
#   mode = xor, aq, aq_n
#   param = desired_error
# Input and output file:
#   xor input  -> xor.data
#   aq input   -> aq_1.data
#   aq_n input -> aq_2.data, run -> aq_2_run.data, output -> aqnoutdata.csv

# %% [markdown]
# ## The number of input variables are controlled: 1 --> More than 1

# %%
# !./ann_aq aq_n 0.00005
df_aqn = pd.read_csv("aqnoutdata.csv")
display( df_aqn)

# print df_aqn.columns.tolist()
plot( df_aqn['in0'][0:5], df_aqn['out'][0:5], 'x-', label='Pred-Pt')
#plot( df_aqn['in0'][5:], df_aqn['out'][5:], '-', label='Pred-Ln')
legend( loc=2)
show()
# Out:
# Run: ann_aq aq_n 0.000050
# Max epochs    50000. Desired error: 0.0000500000.
# Epochs            1. Current error: 0.3246177435. Bit fail 2.
# Epochs         1620. Current error: 0.0000497241. Bit fail 0.
# "in0","in1","out"
# 1.000000,0.280000,-0.198098
# 0.670000,0.460000,-0.406262
# 0.650000,0.410000,-0.501941
# 0.580000,0.490000,-0.534502
# 0.280000,1.000000,-0.984638
#     in0   in1       out
# 0  1.00  0.28 -0.198098
# 1  0.67  0.46 -0.406262
# 2  0.65  0.41 -0.501941
# 3  0.58  0.49 -0.534502
# 4  0.28  1.00 -0.984638
